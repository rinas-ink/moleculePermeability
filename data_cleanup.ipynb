# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
molecules = pd.read_csv('molecules_dataset.csv')

# %%
print(molecules.shape)
print(molecules.dtypes)
molecules.columns = ['id'] + molecules.columns[1:].tolist()
# Out:
# (232, 205)
# id                    int64
# SMILES               object
# SELFIES              object
# BalabanJ            float64
# BertzCT             float64
#                      ...
# fr_unbrch_alkane      int64
# fr_urea               int64
# qed                 float64
# img_file             object
# ACCUMULATION          int64
# Length: 205, dtype: object

# %%
molecules.sample(3)
# Out:
#       id                                             SMILES  \
# 121  123  C=C1C[C@@]23C[C@]1(CC[C@H]3C4=CC=CC(=C4[C@@H]2...
# 94    94  C[C@]12[C@H]3[C@H](C(=O)NC4CC4)[C@@]45CC(=O)[C...
# 162  164  COC(=O)[C@H]1C2=C(C=CC=C2[C@H]3CC[C@]4(C[C@]31...
#
#                                                SELFIES  BalabanJ     BertzCT  \
# 121  [C][=C][C][C@][C][C@][Ring1][Branch1][Branch2]...  1.899349  649.107371
# 94   [C][C@][C@H1][C@H1][Branch1][O][C][=Branch1][C...  1.430734  917.162123
# 162  [C][O][C][=Branch1][C][=O][C@H1][C][=C][Branch...  1.959762  691.920753
#
#           Chi0      Chi0n      Chi0v       Chi1      Chi1n  ...  \
# 121  15.698306  14.076606  14.076606  10.372463   8.663695  ...
# 94   20.844571  16.926868  16.926868  14.243472  11.260593  ...
# 162  15.698306  13.439923  13.439923  10.427305   8.134029  ...
#
#      fr_term_acetylene  fr_tetrazole  fr_thiazole  fr_thiocyan  fr_thiophene  \
# 121                  0             0            0            0             0
# 94                   0             0            0            0             0
# 162                  0             0            0            0             0
#
#      fr_unbrch_alkane  fr_urea       qed             img_file  ACCUMULATION
# 121                 0        0  0.803864  ./IMAGES/mol110.png           100
# 94                  0        0  0.424944   ./IMAGES/mol81.png            53
# 162                 0        0  0.745316  ./IMAGES/mol152.png            28
#
# [3 rows x 205 columns]

# %%
molecules.nunique() == molecules.shape[0]
# Out:
# id                   True
# SMILES              False
# SELFIES             False
# BalabanJ            False
# BertzCT             False
#                     ...
# fr_unbrch_alkane    False
# fr_urea             False
# qed                 False
# img_file             True
# ACCUMULATION        False
# Length: 205, dtype: bool

# %%
def show_duplicates(data):
    grouped = data.groupby(by='SMILES').nunique()
    is_unique = grouped == 1
    strange_rows = is_unique.loc[~is_unique.all(axis=1)].index
    strange_cols = is_unique.loc[strange_rows, ~is_unique.all(axis=0)].columns
    strange_cols = ['SMILES'] + strange_cols.tolist()
    strange_data = molecules.copy()
    strange_data = strange_data.loc[strange_data['SMILES'].isin(strange_rows), strange_cols].sort_values(by='SMILES')
    strange_data['Group'] = strange_data.groupby(by='SMILES').ngroup()
    return strange_data

show_duplicates(molecules)
# Out:
#                                                 SMILES   id  \
# 7    C1=C(C=CC(=C1)S(=O)(=O)O[C@@H]2CO[C@@H]3[C@H](...    7
# 115  C1=C(C=CC(=C1)S(=O)(=O)O[C@@H]2CO[C@@H]3[C@H](...  116
# 169  C1=C(C=CC(=C1)S(=O)(=O)O[C@@H]2CO[C@@H]3[C@H
# 157  [O-]C(=O)[C@H]1C2=C(C=CC=C2[C@H]3CC[C@]4(C[C@]...  159
#
#                 img_file  ACCUMULATION  Group
# 7      ./IMAGES/mol2.png          1647      0
# 115  ./IMAGES/mol103.png          1647      0
# 169  ./IMAGES/mol160.png          1647      0
# 201  ./IMAGES/mol193.png           331      1
# 24     ./IMAGES/mol8.png           331      1
# 6      ./IMAGES/mol1.png          1965      2
# 113  ./IMAGES/mol101.png          1965      2
# 164  ./IMAGES/mol155.png          1965      2
# 148  ./IMAGES/mol138.png           616      3
# 185  ./IMAGES/mol176.png           616      3
# 125  ./IMAGES/mol114.png           946      4
# 173  ./IMAGES/mol164.png           946      4
# 131  ./IMAGES/mol120.png           504      5
# 190  ./IMAGES/mol182.png           504      5
# 22     ./IMAGES/mol6.png           504      5
# 25     ./IMAGES/mol9.png           309      6
# 199  ./IMAGES/mol191.png           309      6
# 1    ./IMAGES/mol127.png           309      6
# 209  ./IMAGES/mol201.png           167      7
# 56    ./IMAGES/mol31.png           232      7
# 55    ./IMAGES/mol30.png           261      7
# 28    ./IMAGES/mol12.png           167      7
# 133  ./IMAGES/mol122.png           458      8
# 192  ./IMAGES/mol184.png           454      8
# 23     ./IMAGES/mol7.png           458      8
# 27    ./IMAGES/mol11.png           204      9
# 207  ./IMAGES/mol199.png           204      9
# 26    ./IMAGES/mol10.png           219     10
# 205  ./IMAGES/mol197.png           219     10
# 142  ./IMAGES/mol132.png           525     11
# 31    ./IMAGES/mol15.png           525     11
# 36    ./IMAGES/mol20.png           176     12
# 116  ./IMAGES/mol104.png           176     12
# 63    ./IMAGES/mol46.png            84     13
# 157  ./IMAGES/mol147.png            84     13

# %%
cleared_molecules = molecules.drop(columns=['img_file'])
cols = [col for col in cleared_molecules.columns if col not in ['id']]
cleared_molecules.drop_duplicates(inplace=True, subset=cols)
show_duplicates(cleared_molecules)
# Out:
#                                                 SMILES   id  ACCUMULATION  \
# 28          C=CC1CN2CCC1CC2C(c1ccnc2c1cc(OC)cc2)[NH3+]   28           167
# 55          C=CC1CN2CCC1CC2C(c1ccnc2c1cc(OC)cc2)[NH3+]   55           261
# 56          C=CC1CN2CCC1CC2C(c1ccnc2c1cc(OC)cc2)[NH3+]   56           232
# 209         C=CC1CN2CCC1CC2C(c1ccnc2c1cc(OC)cc2)[NH3+]  211           167
# 23   C=C[C@]([H])(C[NH3+])[C@H]1CCN2[C@@H](C1)[C@H]...   23           458
# 133  C=C[C@]([H])(C[NH3+])[C@H]1CCN2[C@@H](C1)[C@H]...  135           458
# 192  C=C[C@]([H])(C[NH3+])[C@H]1CCN2[C@@H](C1)[C@H]...  194           454
#
#      Group
# 28       0
# 55       0
# 56       0
# 209      0
# 23       1
# 133      1
# 192      1

# %%
completely_cleared = cleared_molecules.drop([28, 55, 5, 23, 135])
show_duplicates(completely_cleared)
# Out:
# Empty DataFrame
# Columns: [SMILES, Group]
# Index: []

# %%
completely_cleared.to_csv('molecules_dataset_cleared.csv', index=False)
